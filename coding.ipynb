# %%
import sys
sys.version
# Out:
# '3.14.7 (tags/v3.14.7:823f032, Aug  5 2026, 10:51:32) [MSC v.1944 64 bit (AMD64)]'

# %%
print('HI ALL')
# Out:
# HI ALL

# %%
#I AM PYTHON

# %%
a=10

# %%
print(a)
# Out:
# 10

# %%
def test():
    '''
    HI ALL
    '''
    print('hi all')

# %%
test()
# Out:
# hi all

# %%
def test(a,b):
    return a+b
print(f"the sum is: {test(1,2)}.")
# Out:
# the sum is: 3.

# %%
def test(name:str):
    for _ in name:
        print(_)

# %%
test(input('enter name'))
# Out:
# enter name aa
# a
# a

# %%
def test(firstname,lastname):
    return (firstname+' '+lastname).title()
test("amitava" , "chatterjee")
# Out:
# 'Amitava Chatterjee'

# %%
a=test("amitava" , "chatterjee")

# %%
a
# Out:
# 'Amitava Chatterjee'
